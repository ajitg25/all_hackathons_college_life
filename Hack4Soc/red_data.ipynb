# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('books_data.csv')

# %%
books
# Out:
#                                            title  \
# 0                               The Hunger Games
# 1      Harry Potter and the Order of the Phoenix
# 2                          To Kill a Mockingbird
# 4                                       Twilight
# 7                       The Chronicles of Narnia
# ...                                          ...
# 52416                                When I Fall
# 52417                                     Aideen
# 52428                            Nothing To Fear
# 52441            Angel: After the Fall, Volume 1
# 52450                                        Gio
#
#                                                   series  \
# 0                                    The Hunger Games #1
# 1                                        Harry Potter #5
# 2                                  To Kill a Mockingbird
# 4                                   The Twilight Saga #1
# 7      The Chronicles of Narnia (Publication Order) #1–7
# ...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52478 entries, 0 to 52477
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bookId            52478 non-null  object
#  1   title             52478 non-null  object
#  2   series            23470 non-null  object
#  3   author            52478 non-null  object
#  4   rating            52478 non-null  float64
#  5   description       51140 non-null  object
#  6   language          48672 non-null  object
#  7   isbn              52478 non-null  object
#  8   genres            52478 non-null  object
#  9   characters        52478 non-null  object
#  10  bookFormat        51005 non-null  object
#  11  edition           4955 non-null   object
#  12  pages             50131 non-null  object
#  13  publisher         48782 non-null  object
#  14  publishDate       51598 non-null  object
#  15  firstPublishDate  31152 non-null  object
# ...

# %%
books = books[['title','series','author','description','genres','characters','rating','coverImg']]

# %%
books.head()
# Out:
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  \
# 0                            Suzanne Collins
# 1  J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                 Harper Lee
# 3  Jane Austen, Anna Quindlen (Introduction)
# 4                            Stephenie Meyer
#
#                                          description  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1  There is a door at the end of a silent corrido...
# 2  The unforgettable novel of a childhood in a sl...
# 3  Alternate cover edition of ISBN 9780679783268S...
# ...

# %% [markdown]
# # Data Preprocessing

# %%
books.isnull().sum()
# Out:
# title              0
# series         29008
# author             0
# description     1338
# genres             0
# characters         0
# rating             0
# coverImg         605
# dtype: int64

# %%
books.shape
# Out:
# (52478, 8)

# %%
books.dropna(inplace=True)
# Out:
# <ipython-input-557-fe367ec2828d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books.dropna(inplace=True)

# %%
books.isnull().sum()
# Out:
# title          0
# series         0
# author         0
# description    0
# genres         0
# characters     0
# rating         0
# coverImg       0
# dtype: int64

# %%
books.shape
# Out:
# (23205, 8)

# %%
books.head()
# Out:
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 4                                   Twilight
# 7                   The Chronicles of Narnia
#
#                                               series  \
# 0                                The Hunger Games #1
# 1                                    Harry Potter #5
# 2                              To Kill a Mockingbird
# 4                               The Twilight Saga #1
# 7  The Chronicles of Narnia (Publication Order) #1–7
#
#                                       author  \
# 0                            Suzanne Collins
# 1  J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                 Harper Lee
# 4                            Stephenie Meyer
# 7   C.S. Lewis, Pauline Baynes (Illustrator)
#
#                                          description  \
# ...

# %%
books['genres'][0]
# Out:
# "['Young Adult', 'Fiction', 'Dystopia', 'Fantasy', 'Science Fiction', 'Romance', 'Adventure', 'Teen', 'Post Apocalyptic', 'Action']"

# %%
books['rating']
# Out:
# 0        4.33
# 1        4.50
# 2        4.28
# 4        3.60
# 7        4.26
#          ...
# 52472    4.16
# 52473    4.00
# 52474    4.19
# 52475    3.70
# 52477    4.02
# Name: rating, Length: 23205, dtype: float64

# %%
books['rating'] = books['rating'].astype(int)
# Out:
# <ipython-input-563-b724bc4b3733>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books['rating'] = books['rating'].astype(int)

# %%
books
# Out:
#                                            title  \
# 0                               The Hunger Games
# 1      Harry Potter and the Order of the Phoenix
# 2                          To Kill a Mockingbird
# 4                                       Twilight
# 7                       The Chronicles of Narnia
# ...                                          ...
# 52472                               Unbelievable
# 52473                                  Fractured
# 52474                                    Anasazi
# 52475                                     Marked
# 52477                        Daughter of Helaman
#
#                                                   series  \
# 0                                    The Hunger Games #1
# 1                                        Harry Potter #5
# 2                                  To Kill a Mockingbird
# 4                                   The Twilight Saga #1
# 7      The Chronicles of Narnia (Publication Order) #1–7
# ...

# %%
(books['rating']==0).sum()
# Out:
# 7

# %%
dups = books.pivot_table(index = ['rating'], aggfunc ='size')
dups
# Out:
# rating
# 0        7
# 1        2
# 2       19
# 3     9260
# 4    13870
# 5       47
# dtype: int64

# %%
len(books['characters'][52475])
# Out:
# 2

# %%
# books[books['characters'].map(len) < 2].index
books.drop(books[books['characters'].map(len) <= 2].index, inplace=True)
# Out:
# C:\Users\ajitg\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
books.shape
# Out:
# (9021, 8)

# %%
dups = books.pivot_table(index = ['rating'], aggfunc ='size')
dups
# Out:
# rating
# 2       1
# 3    3727
# 4    5293
# dtype: int64

# %%
dups = books.pivot_table(index = ['genres'], aggfunc ='size')

# %%
dups
# Out:
# genres
# ['Abuse', 'Dark', 'M M Romance', 'Romance', 'New Adult', 'Contemporary', 'Young Adult', 'Erotica', 'Mental Illness', 'BDSM']                               1
# ['Adventure', 'Childrens', 'Fiction', 'Mystery', 'Juvenile', 'Young Adult', 'Middle Grade', 'Indonesian Literature', 'Action', 'Reference']                1
# ['Adventure', 'Childrens', 'Fiction', 'Mystery', 'Young Adult', 'Middle Grade', 'Indonesian Literature', 'British Literature', 'Juvenile', 'Classics']     1
# ['Adventure', 'Fantasy', 'Fiction', 'Classics', 'Novels', 'Historical Fiction', 'Historical', 'Science Fiction', '20th Century', 'Africa']                 1
# ['Adventure', 'Fiction', 'Fantasy', 'Classics', 'Pulp', 'Action', 'Science Fiction', 'Historical Fiction', 'Africa', 'Science Fiction Fantasy']            1
#                                                                                                                                                           ..
# ...

# %%
books['genres']
# Out:
# 0        ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1        ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2        ['Classics', 'Fiction', 'Historical Fiction', ...
# 4        ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# 7        ['Fantasy', 'Classics', 'Fiction', 'Young Adul...
#                                ...
# 52416    ['Romance', 'New Adult', 'Contemporary Romance...
# 52417    ['Romance', 'New Adult', 'Contemporary Romance...
# 52428    ['Romantic Suspense', 'Romance', 'Suspense', '...
# 52441    ['Graphic Novels', 'Comics', 'Fantasy', 'Vampi...
# 52450    ['Romance', 'New Adult', 'Contemporary Romance...
# Name: genres, Length: 9021, dtype: object

# %%
books['genres'][0][0]
# Out:
# '['

# %%
books['genres'] = books.genres.apply(lambda x: x[1:-1].split(','))
# Out:
# <ipython-input-575-1752cba2f784>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books['genres'] = books.genres.apply(lambda x: x[1:-1].split(','))

# %%
books['genres'][0][5]
# Out:
# " 'Romance'"

# %%
import re

res1 = "".join(re.split("[^a-zA-Z]*", books['genres'][0][5]))
res1
# Out:
# 'Romance'

# %%
# books['genres'] = books.genres.apply(lambda x: x.strip('()').split(','))
# books['genres'] = books.genres.apply(lambda x: "".join(re.split("[^a-zA-Z]*", x)))

# books['genres'][0][0]
# books.drop(books.index[3:8], inplace=True)
ind = 0;
for i in books['genres']:
#     print(i)
    xx = []
    for j in i:
        
        a = j.replace("'", '')
        a = a.strip()
        xx.append(a)
#     print(xx)
    books['genres'][ind] = xx
    ind+=1
#     print((books['genres'][i]))
#     for j in range(len((books['genres'][i]))):
#         a.replace('"', '')
#         print(books['genres'][i][j])
#         books['genres'][i][j] = "".join(re.split("[^a-zA-Z]*", books['genres'][i][j]))
# Out:
# <ipython-input-578-f2cfbab3c0c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books['genres'][ind] = xx
# C:\Users\ajitg\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\ajitg\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# books['characters'] = books.genres.apply(lambda x: x[1:-1].split(','))
# ind = 0;
# for i in books['characters']:
# #     print(i)
#     xx = []
#     for j in i:
        
#         a = j.replace("'", '')
#         a = a.strip()
#         xx.append(a)
# #     print(xx)
#     books['characters'][ind] = xx
#     ind+=1
books['characters'][0][0]
# Out:
# '['

# %%
books['genres'][0][1]
# Out:
# 'Fiction'

# %%
for i in books['genres']:
    print(i)
# Out:
# ['Young Adult', 'Fiction', 'Dystopia', 'Fantasy', 'Science Fiction', 'Romance', 'Adventure', 'Teen', 'Post Apocalyptic', 'Action']
# ['Fantasy', 'Young Adult', 'Fiction', 'Magic', 'Childrens', 'Adventure', 'Audiobook', 'Middle Grade', 'Classics', 'Science Fiction Fantasy']
# ['Classics', 'Fiction', 'Historical Fiction', 'School', 'Literature', 'Young Adult', 'Historical', 'Novels', 'Read For School', 'High School']
# ['Fantasy', 'Classics', 'Fiction', 'Young Adult', 'Childrens', 'Christian', 'Adventure', 'Science Fiction Fantasy', 'Middle Grade', 'Christian Fiction']
# ['Fiction', 'Mystery', 'Thriller', 'Suspense', 'Mystery Thriller', 'Historical Fiction', 'Adventure', 'Novels', 'Crime', 'Adult']
# ['Classics', 'Fantasy', 'Fiction', 'Childrens', 'Young Adult', 'Literature', 'Adventure', 'Novels', '19th Century', 'British Literature']
# ['Science Fiction', 'Fiction', 'Young Adult', 'Fantasy', 'Classics', 'Science Fiction Fantasy', 'Dystopia', 'War', 'Audiobook', 'Adventure']
# ...

# %%
books['genres'].unique
# Out:
# <bound method Series.unique of 0        [Young Adult, Fiction, Dystopia, Fantasy, Scie...
# 1        [Fantasy, Young Adult, Fiction, Magic, Childre...
# 2        [Classics, Fiction, Historical Fiction, School...
# 4        [Fantasy, Classics, Fiction, Young Adult, Chil...
# 7        [Fiction, Mystery, Thriller, Suspense, Mystery...
#                                ...
# 52416    ['Romance',  'New Adult',  'Contemporary Roman...
# 52417    ['Romance',  'New Adult',  'Contemporary Roman...
# 52428    ['Romantic Suspense',  'Romance',  'Suspense',...
# 52441    ['Graphic Novels',  'Comics',  'Fantasy',  'Va...
# 52450    ['Romance',  'New Adult',  'Contemporary Roman...
# Name: genres, Length: 9021, dtype: object>

# %%
books["genres"].explode().unique().sum()
# Out:
# "Young AdultFictionDystopiaFantasyScience FictionRomanceAdventureTeenPost ApocalypticActionMagicChildrensAudiobookMiddle GradeClassicsScience Fiction FantasyHistorical FictionSchoolLiteratureHistoricalNovelsRead For SchoolHigh SchoolChristianChristian FictionMysteryThrillerSuspenseMystery ThrillerCrimeAdult19th CenturyBritish LiteratureWarHorrorVampiresGothicParanormalSupernaturalEpic FantasyHigh FantasyDragonsEpicHumorUnfinishedAmericanTime TravelHistorical RomanceScotlandFeminismLGBTAfrican AmericanRussiaRussian LiteraturePhilosophyClassic LiteratureReligionChick LitContemporaryAdult FictionContemporary RomanceLoveDramaYoung Adult FantasyJuvenilePoetryItalian LiteratureItalyGerman LiteratureWorld War IUrban FantasyParanormal RomanceFranceFrench LiteratureMythologyGreek MythologySwedenSteampunkTudor PeriodDinosaursAngelsWerewolvesRetellingsFairy TalesPortugalPortuguese LiteratureSurvivalNew AdultCollegeShort StoriesDetectiveEroticaBDSMErotic RomanceCyberpunkPicture BooksMonstersStor
# ...

# %%
books['genres'][0]
# Out:
# ['Young Adult',
#  'Fiction',
#  'Dystopia',
#  'Fantasy',
#  'Science Fiction',
#  'Romance',
#  'Adventure',
#  'Teen',
#  'Post Apocalyptic',
#  'Action']

# %%
print(books['genres'][0])

list1 = ['Comics', 'Science','Fiction','Adventure','Action','Comedy','Crime','Biography','Philosophy','Psychology','Paranormal','Poetry','Detective','Gods']
# books.index[len(list(set(list1).intersection(books['genres'][0])))==0]
set(list1).intersection(books['genres'][0])
# Out:
# ['Young Adult', 'Fiction', 'Dystopia', 'Fantasy', 'Science Fiction', 'Romance', 'Adventure', 'Teen', 'Post Apocalyptic', 'Action']
# {'Action', 'Adventure', 'Fiction'}

# %%
for i in books['genres']:
    print(i)
# Out:
# ['Young Adult', 'Fiction', 'Dystopia', 'Fantasy', 'Science Fiction', 'Romance', 'Adventure', 'Teen', 'Post Apocalyptic', 'Action']
# ['Fantasy', 'Young Adult', 'Fiction', 'Magic', 'Childrens', 'Adventure', 'Audiobook', 'Middle Grade', 'Classics', 'Science Fiction Fantasy']
# ['Classics', 'Fiction', 'Historical Fiction', 'School', 'Literature', 'Young Adult', 'Historical', 'Novels', 'Read For School', 'High School']
# ['Fantasy', 'Classics', 'Fiction', 'Young Adult', 'Childrens', 'Christian', 'Adventure', 'Science Fiction Fantasy', 'Middle Grade', 'Christian Fiction']
# ['Fiction', 'Mystery', 'Thriller', 'Suspense', 'Mystery Thriller', 'Historical Fiction', 'Adventure', 'Novels', 'Crime', 'Adult']
# ['Classics', 'Fantasy', 'Fiction', 'Childrens', 'Young Adult', 'Literature', 'Adventure', 'Novels', '19th Century', 'British Literature']
# ['Science Fiction', 'Fiction', 'Young Adult', 'Fantasy', 'Classics', 'Science Fiction Fantasy', 'Dystopia', 'War', 'Audiobook', 'Adventure']
# ...

# %%
for i in books['genres']:
    print(set(list1).intersection(i))
# Out:
# {'Action', 'Fiction', 'Adventure'}
# {'Fiction', 'Adventure'}
# {'Fiction'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Crime', 'Adventure'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Paranormal'}
# {'Fiction', 'Adventure'}
# {'Fiction'}
# {'Fiction'}
# {'Adventure'}
# {'Fiction'}
# {'Fiction', 'Philosophy'}
# {'Fiction'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Philosophy', 'Poetry'}
# {'Fiction'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Paranormal'}
# {'Action', 'Fiction', 'Adventure'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Paranormal'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Crime'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Adventure'}
# {'Fiction'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Adventure'}
# {'Fiction', 'Paranormal'}
# {'Fiction', 'Paranormal'}
# ...

# %%
# books = books.drop(books[len(set(list1).intersection(books['genres']))==0].index)
ind =0
ind_list = []
for i in books['genres']:
    if(len(set(list1).intersection(i))>2):
        ind_list.append(ind)
    ind+=1
print(len(ind_list))
new_df = books.iloc[ind_list]
# Out:
# 509

# %%
new_df
# Out:
#                          title  \
# 0             The Hunger Games
# 7     The Chronicles of Narnia
# 60         The Handmaid's Tale
# 64    The Pillars of the Earth
# 104            Clockwork Angel
# ...                        ...
# 8851     The Search for WondLa
# 8878           The Great Brain
# 8940                   Magonia
# 8959               DragonQuest
# 9009         Doctored Evidence
#
#                                                  series  \
# 0                                   The Hunger Games #1
# 7     The Chronicles of Narnia (Publication Order) #1–7
# 60                               The Handmaid's Tale #1
# 64                                       Kingsbridge #1
# 104                             The Infernal Devices #1
# ...                                                 ...
# 8851                           The Search for WondLa #1
# 8878                                 The Great Brain #1
# 8940                                         Magonia #1
# ...

# %%
student_result = pd.ExcelWriter('StudentResult.xlsx')
  
# write students data to excel
new_df.to_excel(student_result)
  
# save the students result excel
student_result.save()

# %%
file_name = 'web_data.xlsx'
  
# saving the excelsheet
new_df.to_excel(file_name)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-591-84a15bf522de> in <module>
#       2
#       3 # saving the excelsheet
# ----> 4 new_df.to_excel(file_name)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2187             inf_rep=inf_rep,
#    2188         )
# -> 2189         formatter.write(
#    2190             excel_writer,
#    2191             sheet_name=sheet_name,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
# ...

# %%
data = new_df.to_json(orient='index')
data

# %%
import json

json_object = json.dumps(data, indent=4)
 
# Writing to sample.json
with open("sample.json", "w") as outfile:
    outfile.write(json_object)
